# %% [markdown]
# <a href="https://colab.research.google.com/github/Somupatil80/EDA-Paisabazaar-Banking-Fraud-Analysis-/blob/main/Capstone_Project_2_Exploratory_Data_Analysis_(Paisabazaar_Banking_Fraud_Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA (Exploratory Data Analysis)
# ##### **Contribution**    - Individual
# ##### **Member Name** - Somangouda Veerangouda Police Patil

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# **Paisabazaar Banking Fraud Analysis**
#
# This project focuses on developing a **Credit Score Classification** system for **Paisabazaar**, a leading financial services platform that helps customers compare and apply for loans, credit cards, and other financial products. One of the most critical aspects of financial decision-making is evaluating a customer's creditworthiness before approving loans or issuing credit. A credit score reflects an individual's financial behavior and repayment capability, enabling financial institutions to minimize lending risks. This project aims to build a predictive model that classifies customers into different credit score categories based on their financial and behavioral information.
#
# The project begins with an in-depth analysis of the customer dataset, which contains various attributes such as annual income, monthly salary, outstanding debt, number of bank accounts, number of credit cards, loan details, payment history, delayed payments, credit utilization ratio, age of credit history, monthly balance, and other financial indicators. These features collectively provide valuable insights into a customer's financial health and credit behavior.
#
# The first stage of the project involves **data preprocessing and cleaning**. Since real-world financial datasets often contain missing values, duplicate records, incorrect data types, and inconsistent entries, extensive preprocessing is performed to improve data quality. Missing values are handled using appropriate imputation techniques, categorical variables are encoded, and numerical features are standardized where necessary. Outliers are identified and treated to ensure they do not negatively affect model performance.
#
# Following data preparation, **Exploratory Data Analysis (EDA)** is conducted to understand the relationships between different variables and identify important trends. Statistical summaries and visualizations help reveal patterns in customer behavior, income distribution, debt levels, payment delays, and credit utilization. Correlation analysis is also performed to determine the strength of relationships between variables and identify the most influential features contributing to credit score classification.
#
# The project extensively utilizes Python's data analysis and visualization libraries. **Pandas** is used for data loading, cleaning, transformation, and manipulation, while **NumPy** supports efficient numerical operations. **Matplotlib** and **Seaborn** are employed to generate clear and informative visualizations such as histograms, box plots, scatter plots, count plots, correlation heatmaps, and distribution plots. Additionally, **Plotly** provides interactive visualizations that allow users to explore customer data dynamically and gain deeper insights into financial trends.
#
# After feature engineering and selection, multiple **Machine Learning classification algorithms** can be trained to predict customer credit scores. Algorithms such as Logistic Regression, Decision Tree, Random Forest, Support Vector Machine (SVM), XGBoost, or Gradient Boosting may be evaluated to identify the best-performing model. Model performance is measured using evaluation metrics including accuracy, precision, recall, F1-score, confusion matrix, and cross-validation techniques to ensure robustness and reliability.
#
# The overall project architecture follows a structured pipeline consisting of data collection, preprocessing, exploratory analysis, feature engineering, model training, model evaluation, and prediction. This modular approach ensures scalability, reproducibility, and ease of maintenance.
#
# The final outcome of the project is a predictive system capable of accurately classifying customers into different credit score categories such as **Poor**, **Standard**, or **Good**. Such a system enables Paisabazaar to make faster and more reliable credit assessments, reduce the probability of loan defaults, improve risk management, and provide personalized financial product recommendations. By leveraging data analytics and machine learning, the project demonstrates how intelligent credit score classification can support better business decisions, enhance customer experience, and contribute to more efficient financial services.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Financial institutions rely on accurate credit score assessment to evaluate a customer's creditworthiness before approving loans, credit cards, or other financial products. Traditional credit evaluation methods can be time-consuming and may not effectively analyze the growing volume and complexity of customer financial data. This can lead to incorrect credit risk assessments, increased loan defaults, and less personalized financial recommendations.
#
# The objective of this project is to develop a **Machine Learning-based Credit Score Classification System** for Paisabazaar that predicts a customer's credit score category using financial and behavioral attributes such as annual income, credit utilization, outstanding debt, payment history, number of loans, and credit card usage. The project involves data preprocessing, exploratory data analysis (EDA), feature engineering, and model development to accurately classify customers into credit score categories (Poor, Standard, or Good). The resulting model aims to support faster, more accurate credit decisions, improve risk management, reduce default rates, and enhance customer financial product recommendations.

# %% [markdown]
# ### **Business Objective**
#
# The primary business objective of this project is to develop a reliable and accurate **Credit Score Classification System** that predicts a customer's credit score category based on their financial and behavioral data. By leveraging machine learning techniques, the project aims to help **Paisabazaar** improve the efficiency and accuracy of its credit assessment process, enabling financial institutions to make informed lending decisions.
#
# The project seeks to reduce the risk of loan defaults by identifying customers with different levels of creditworthiness, streamline the loan approval process through automated credit score prediction, and support personalized financial product recommendations. Additionally, the model aims to enhance risk management, improve customer experience, and enable data-driven decision-making, ultimately benefiting both financial institutions and customers through faster, more reliable, and fair credit evaluations.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# Import Pandas for data manipulation and analysis
import pandas as pd

# Import NumPy for numerical computations and array operations
import numpy as np

# Import Matplotlib for creating basic plots and visualizations
import matplotlib.pyplot as plt

# Import Seaborn for statistical data visualization with attractive plots
import seaborn as sns

# Import Plotly Express for creating interactive and dynamic visualizations
import plotly.express as px

# Import Plotly Graph Objects for building customized interactive charts
import plotly.graph_objects as go

# Import Plotly Offline to display interactive plots in Google Colab/Jupyter Notebook
from plotly.offline import init_notebook_mode

# Initialize Plotly to render interactive charts inside the notebook
init_notebook_mode(connected=True)

# Ignore warning messages to keep the notebook output clean
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Read the CSV dataset and store it in a DataFrame named 'data'
data=pd.read_csv('/content/drive/MyDrive/dataset.csv')
data

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()  # Display the first five records to verify that the dataset has loaded correctly

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# Display the total number of rows and columns present in the dataset
print("Number of Rows:", data.shape[0])
print("Number of Columns:", data.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()  # Display the structure and information of the dataset

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()  # Count the total number of duplicate rows in the dataset

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()  # Count the total number of missing values in each column of the dataset

# %%
# Visualizing the missing values

# Create a figure with a width of 10 inches and a height of 5 inches
plt.figure(figsize=(10,5))

# Visualize the missing values in the dataset using a heatmap
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')

# Add a title to the heatmap
plt.title("Missing Values Heatmap")

# Display the heatmap
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In the initial stage of the project, we first imported the required Python libraries and loaded the dataset into the working environment. We then examined the dataset by identifying the total number of rows and columns, reviewing its structure and data types using dataset information, checking for duplicate records and missing values, and finally visualized the missing values using a heatmap to better understand the data quality before proceeding with preprocessing and analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns  # Display the names of all columns (features) present in the dataset

# %%
# Dataset Describe
data.describe()  # Display the statistical summary of all numerical columns in the dataset

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Variable Name - Description**
#
#
# 1.   **ID** - Unique identifier for each customer record.
#
# 2.   **Customer_ID** - Unique identification number assigned to each customer.
#
# 1.  **Month** - Month in which the customer data was recorded.
#
# 1.   **Name** - Customer's name.
#
# 1.   **Age** - Age of the customer in years.
#
# 1.   **SSN** -	Social Security Number of the customer.
#
# 1.  **Occupation** - Customer's profession or occupation.
#
# 1.   **Annual_Income** -	Total annual income earned by the customer.
#
# 1.   **Monthly_Inhand_Salary** -	Customer's monthly take-home salary.
#
# 1.  **Num_Bank_Accounts** - Number of bank accounts owned by the customer.
#
# 1.  **Num_Credit_Card**	 - Number of credit cards held by the customer.
#
# 1.  **Interest_Rate**	 - Interest rate applied to the customer's loans or credit.
# 2.   **Num_of_Loan**	- Total number of loans taken by the customer.
#
#
# 2.   **Type_of_Loan**	- Types of loans (e.g., Home Loan, Personal Loan, Auto Loan).
#
# 2.   **Delay_from_due_date**	- Number of days the customer delayed payments beyond the due date.
#
# 2.   **Num_of_Delayed_Payment**	- Total number of delayed payments made by the customer.
# 1.   **Changed_Credit_Limit** - 	Change in the customer's credit limit over time.
# 1.   **Num_Credit_Inquiries** - 	Number of times the customer's credit report was checked.
# 1.  **Credit_Mix**	- Types of credit accounts held by the customer (Good, Standard, Bad).
# 1.   **Outstanding_Debt**	 - Total unpaid debt owed by the customer.
# 1.   **Credit_Utilization_Ratio**	 - Percentage of available credit currently being used.
# 1.   **Credit_History_Age**	 - Length of the customer's credit history.
#
# 2.   **Payment_of_Min_Amount**	- Indicates whether the customer pays the minimum amount due (Yes/No).
# 2.   **Total_EMI_per_month**	 - Total Equated Monthly Installment (EMI) paid each month.
# 2.  **Amount_invested_monthly** - Monthly investment amount made by the customer.
# 2.   **Payment_Behaviour** - 	Customer's payment pattern and spending behavior.
# 2.   **Monthly_Balance**	 - Remaining account balance after monthly transactions.
# 2.  **Credit_Score**	- Target variable indicating the customer's credit score category (Poor, Standard, Good).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data.nunique()  # Display the number of unique values in each column of the dataset

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
data.info()

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Load Dataset
df = pd.read_csv('/content/drive/MyDrive/dataset.csv')

# -----------------------------
# 1. Remove Duplicate Records
# -----------------------------
df.drop_duplicates(inplace=True)

# -----------------------------
# 2. Replace Invalid Values
# -----------------------------
df.replace(['_', 'NA', '?', ''], np.nan, inplace=True)

# -----------------------------
# 3. Check Missing Values
# -----------------------------
print(df.isnull().sum())

# -----------------------------
# 4. Convert Data Types
# -----------------------------
numeric_columns = [
    'Age',
    'Annual_Income',
    'Monthly_Inhand_Salary',
    'Num_Bank_Accounts',
    'Num_Credit_Card',
    'Interest_Rate',
    'Num_of_Loan',
    'Delay_from_due_date',
    'Num_of_Delayed_Payment',
    'Changed_Credit_Limit',
    'Num_Credit_Inquiries',
    'Outstanding_Debt',
    'Credit_Utilization_Ratio',
    'Total_EMI_per_month',
    'Amount_invested_monthly',
    'Monthly_Balance'
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# -----------------------------
# 5. Handle Missing Values
# -----------------------------
for col in numeric_columns:
    df[col].fillna(df[col].median(), inplace=True)

categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# -----------------------------
# 6. Remove Unnecessary Columns
# -----------------------------
df.drop(['ID', 'Customer_ID', 'Name', 'SSN'], axis=1, inplace=True)

# -----------------------------
# 7. Verify Dataset
# -----------------------------
print(df.info())
print(df.isnull().sum())
print(df.head())

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *  The dataset initially contained duplicate records, which were removed to improve data quality.
#
#
# *   Several columns had missing values and inconsistent entries (such as _, NA, and ?), which were successfully cleaned.
#
# *  Some numerical columns were stored as object (string) data types and required conversion before analysis.
#
# *   Identifier columns (ID, Customer_ID, Name, and SSN) were not useful for prediction and were removed.
# *   Identifier columns (ID, Customer_ID, Name, and SSN) were not useful for prediction and were removed.
#
#
# *  After preprocessing, the dataset contained clean, consistent, and machine-readable data with appropriate data types.
#
#
# *   The cleaned dataset became suitable for Exploratory Data Analysis (EDA), visualization, feature engineering, and building a Credit Score Classification machine learning model.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# Credit Score Distribution (Count Plot)

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a count plot to visualize the number of customers in each Credit Score category
sns.countplot(x='Credit_Score', data=data, palette='viridis')

# Add a title to the chart
plt.title("Distribution of Credit Score Categories")

# Label the x-axis
plt.xlabel("Credit Score")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Count Plot (Bar Chart) was selected because the target variable Credit_Score is a categorical variable with three categories: Poor, Standard, and Good. A count plot is the most appropriate visualization for comparing the frequency of each category. It provides a clear representation of the distribution of customers across different credit score groups, making it easy to identify the dominant category and any class imbalance in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of customers among the three credit score categories.
#
# *   The Standard credit score category contains the highest number of customers, indicating that most individuals maintain an average level of financial health.
# *  The Good credit score category represents customers who have responsible repayment behavior, lower debt levels, and better financial management.
#
#
#
# *   The Poor credit score category includes customers who are more likely to have delayed payments, higher outstanding debt, and lower repayment capacity.
#
# This distribution provides an overview of the customer base and highlights how customers are spread across different creditworthiness levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  **Business Impact -** Yes.
#
# The insights from this chart can significantly improve Paisabazaar's business decisions by enabling customer segmentation based on creditworthiness.
#
# Some positive business impacts include:
#
#
# *   Identifying the largest customer segment for targeted financial products.
# Designing personalized loan and credit card offers according to different credit score groups.
# *   Providing premium financial products and lower interest rates to customers with Good credit scores.
#
#
#
#
#
#
# *   Offering financial awareness programs and credit improvement recommendations to customers with Poor credit scores.
# *   Improving credit risk assessment and increasing loan approval efficiency.
#
#
# Overall, understanding the distribution of credit scores helps Paisabazaar make data-driven lending decisions while enhancing customer satisfaction.
#
# **Negative Impact -** Yes.
#
# If the chart indicates that a significant proportion of customers fall into the Poor credit score category, it may negatively affect business performance.
#
# This is because:
#
#
# *   Customers with poor credit scores have a higher probability of loan default.
# *   Increased defaults can lead to financial losses for lending institutions.
#
#
#
#
# *   The company may need to spend additional resources on debt recovery and credit monitoring.
# *  A higher percentage of risky customers may reduce the overall profitability of loan products.
#
#
#
#
#
#
#
# Therefore, Paisabazaar should carefully evaluate customers with Poor credit scores before approving loans and provide financial guidance to help improve their creditworthiness.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Age Distribution (Histogram)

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a histogram to visualize the distribution of customer ages
sns.histplot(data['Age'], bins=30, color='skyblue')

# Add a title to the chart
plt.title("Distribution of Customer Age")

# Label the x-axis
plt.xlabel("Age")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the histogram
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram was chosen because Age is a continuous numerical variable. Histograms are ideal for understanding how numerical data is distributed by grouping values into intervals (bins). This chart helps identify the most common age groups, detect skewness, and observe any unusual patterns or outliers in the customer age distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that the majority of customers fall within the working-age group, indicating that most individuals in the dataset are financially active and likely to use banking and credit services.
#
# Additional observations include:
#
#
# *   Most customers are concentrated within a specific age range, forming the largest customer segment.
#
# *  Very few customers belong to the younger or older age groups.
# *  The distribution provides an understanding of the demographic profile of Paisabazaar's customers.
#
#
# *   Age appears to be an important factor that may influence borrowing behavior and repayment capacity.
#
# This insight helps identify the age groups that are most likely to apply for financial products and services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impaact -** Yes.
#
# Understanding the age distribution enables Paisabazaar to develop more targeted financial products and marketing strategies.
#
# Some positive business impacts include:
#
#
# *   Designing age-specific loan, insurance, and investment products.
#
# *  Offering education loans or starter credit cards to younger customers.
# Providing home loans, vehicle loans, and personal loans to working professionals.
# *   Recommending retirement planning and wealth management products to older customers.
#
#
# *   Improving customer segmentation and personalized financial recommendations.
#
#
# These insights help the company improve customer satisfaction while increasing the effectiveness of product recommendations.
#
# **Negative Impact -** Yes.
#
# The chart may reveal that customers in the very young or older age groups represent a smaller portion of the dataset and may have lower borrowing potential.
#
# Reasons include:
#
#
# *  Younger customers often have limited income, shorter credit histories, and lower financial stability, making them less eligible for large loans.
# *  Older customers nearing retirement may have reduced income or lower repayment capacity, increasing lending risk.
#
# *   Lending to customers with limited repayment ability can increase the probability of loan defaults.
# *   Financial institutions may need stricter eligibility criteria for these age groups, which could reduce the number of approved applications.
#
#
#
#
#
#
#
#
#
# Therefore, while age is not the only factor affecting creditworthiness, it plays an important role in assessing customer risk and determining suitable financial products.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Annual Income Distribution

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a histogram to visualize the distribution of customers' annual income
sns.histplot(data['Annual_Income'], bins=30, color='green')

# Add a title to the chart
plt.title("Distribution of Annual Income")

# Label the x-axis
plt.xlabel("Annual Income")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the histogram
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram was chosen because Annual Income is a continuous numerical variable. Histograms are useful for understanding how income is distributed among customers by grouping similar income values into intervals. This visualization helps identify the most common income range, detect income variations, and understand the overall financial profile of customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram indicates that most customers belong to the middle-income group, while comparatively fewer customers fall into the very low-income or very high-income categories.
#
# Additional insights include:
#
#
# *  The majority of customers have moderate annual incomes, suggesting they represent the primary customer base.
#
# *   Only a small proportion of customers earn significantly high incomes.
# *   Some customers belong to lower-income groups, which may affect their borrowing capacity.
# *   The income distribution provides a clear understanding of customers' financial strength and repayment potential.
#
# These observations help identify the economic profile of customers and their ability to manage loans and credit products.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# Understanding customers' annual income enables Paisabazaar to make better lending decisions and provide personalized financial services.
#
# Some positive business impacts include:
#
#
# *   Recommending loan amounts based on customers' income levels.
#
# *   Offering customized credit cards and financial products that match customers' repayment capacity.
# *  Improving loan approval decisions by evaluating customers' affordability.
# Designing targeted marketing campaigns for different income groups.
#
#
# *  Reducing financial risk by aligning loan eligibility with customers' income.
# These insights help improve customer satisfaction while supporting responsible lending practices.
#
# **Negative Impacts -** Yes.
#
# The presence of a significant number of lower-income customers may increase financial risk for the company.
#
# Reasons include:
#
#
# *   Customers with lower annual incomes may have limited repayment capacity.
#
#
# *  They are more likely to experience financial difficulties during loan repayment.
#
# *  Higher repayment risk can lead to increased loan defaults and financial losses.
#
#
#
# *   The company may need stricter eligibility criteria or lower loan limits for these customers.
#
#
#
#
#
# Therefore, annual income is an important factor in assessing a customer's creditworthiness and minimizing lending risk.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# Monthly Salary Distribution

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a histogram to visualize the distribution of customers' monthly in-hand salaries
sns.histplot(data['Monthly_Inhand_Salary'], bins=30, color='orange')

# Add a title to the chart
plt.title("Distribution of Monthly In-hand Salary")

# Label the x-axis
plt.xlabel("Monthly In-hand Salary")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the histogram
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram was selected because Monthly_Inhand_Salary is a continuous numerical variable. Histograms are effective for showing how salary values are distributed across customers by grouping them into intervals (bins). This visualization helps identify the most common salary ranges, detect salary variations, and understand the earning capacity of customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most customers earn moderate monthly salaries, indicating that the majority of customers have a stable monthly income.
#
# Additional observations include:
#
#
# *   A large proportion of customers fall within the middle salary range.
#
# *   Only a small number of customers have very low or very high monthly salaries.
#
# *  Customers with higher salaries generally have greater financial flexibility and repayment capacity.
#
#
# *   Monthly salary is an important indicator of a customer's ability to manage EMIs, loans, and other financial commitments.
#
#
#
#
#
#
# This analysis provides a clear understanding of customers' monthly earning patterns and financial stability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impact -** Yes.
#
# Monthly salary plays a significant role in evaluating a customer's repayment ability and helps Paisabazaar make better financial recommendations.
#
# Some positive business impacts include:
#
# *   Recommending appropriate EMI amounts based on customers' monthly income.
#
# *   Improving loan approval decisions by assessing repayment affordability.
# *   Offering customized loan amounts and repayment plans.
#
#
# *   Identifying customers eligible for premium banking products and higher credit limits.
#
# *   Enhancing customer satisfaction through personalized financial solutions.
#
# These insights help reduce lending risk while improving the overall customer experience.
#
# **Negative Impact -** Yes.
#
# Customers with low monthly salaries may present a higher financial risk.
#
# Reasons include:
#
# *   They may have limited disposable income after covering essential living expenses.
#
# *   Managing high EMIs or multiple loans can become difficult, increasing the likelihood of delayed payments.
# *  Lower repayment capacity can lead to loan defaults, affecting the financial institution's profitability.
#
#
# *   Additional credit risk assessments may be required before approving loans for customers with lower monthly incomes.
#
#
# Therefore, monthly salary is an important factor in determining a customer's borrowing capacity and minimizing credit risk.

# %% [markdown]
# ####Chart - 5

# %%
# chart - 5 viualization code

# Credit Score vs Annual Income (Box Plot)

# Create a figure with a width of 8 inches and a height of 6 inches
plt.figure(figsize=(8,6))

# Create a box plot to compare Annual Income across different Credit Score categories
sns.boxplot(x='Credit_Score', y='Annual_Income', data=data, palette='viridis')

# Add a title to the chart
plt.title("Annual Income Distribution Across Credit Score Categories")

# Label the x-axis
plt.xlabel("Credit Score")

# Label the y-axis
plt.ylabel("Annual Income")

# Display the chart
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
#   A Box Plot was selected because it is the most suitable chart for comparing the distribution of a numerical variable (Annual Income) across a categorical variable (Credit Score). It clearly displays the median, quartiles, overall spread, and outliers of annual income for each credit score category (Poor, Standard, and Good). This helps determine whether customers with different credit scores also differ in their income levels.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot compares the annual income of customers across the three credit score categories.
#
# From the analysis, the following insights can be observed:
#
# *   Customers with a Good Credit Score generally tend to have higher annual incomes, indicating stronger financial stability and better repayment capacity.
#
# *  Customers with a Standard Credit Score typically fall within the middle-income range, representing average earning potential and moderate financial health.
# *   Customers with a Poor Credit Score often have comparatively lower annual incomes, which may affect their ability to repay loans on time.
#
# *   The chart may also reveal outliers, showing that a few customers earn exceptionally high or low incomes regardless of their credit score. This suggests that income alone does not determine creditworthiness, and other factors such as repayment history, outstanding debt, and credit utilization also influence the credit score.
#
#
# Overall, the chart demonstrates a relationship between annual income and credit score while highlighting that multiple financial factors contribute to a customer's credit profile.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
#
#     Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar make better financial and lending decisions.
#
# Some positive business impacts include:
#
# *   Identifying customers who are eligible for higher-value loans based on their income and credit score.
#
# *   Recommending customized loan amounts that match customers' repayment capacity.
# *   Offering premium financial products and lower interest rates to customers with strong income and good credit history.
#
# *   Improving customer segmentation by classifying customers according to both income level and creditworthiness.
#
# *  Enhancing the accuracy of credit risk assessment by considering annual income as an important financial indicator.
#
# These insights enable Paisabazaar to make more informed lending decisions while improving customer satisfaction and reducing financial risk.
#
# **Negative Impacts -** Yes.
#
# The chart may indicate that customers with lower annual incomes are more likely to have Poor credit scores, which can negatively impact business performance.
#
# Reasons include:
#
# *   Lower-income customers may have limited financial resources to manage EMIs, loan repayments, and daily expenses.
# *  Reduced repayment capacity increases the likelihood of delayed payments and loan defaults.
#
# *   Approving large loans for customers with low income may increase the company's financial risk.
# *   Although some customers may earn high incomes, they can still have Poor credit scores due to factors such as excessive debt, frequent delayed payments, or poor financial management. Therefore, income should not be the only criterion used for loan approval.
#
# Paisabazaar should evaluate annual income along with other financial indicators before making lending decisions to minimize credit risk.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# 6. Credit Score by Occupation

# Create a figure with a width of 14 inches and a height of 6 inches
plt.figure(figsize=(14,6))

# Create a count plot to compare the distribution of Credit Score across different occupations
sns.countplot(x='Occupation', hue='Credit_Score', data=data, palette='viridis')

# Add a title to the chart
plt.title("Credit Score Distribution Across Occupations")

# Label the x-axis
plt.xlabel("Occupation")

# Label the y-axis
plt.ylabel("Number of Customers")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the legend
plt.legend(title="Credit Score")

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Count Plot with a Hue was chosen because both Occupation and Credit_Score are categorical variables. This chart allows us to compare the distribution of customers with Poor, Standard, and Good credit scores across different occupations. It provides a clear visual comparison of how creditworthiness varies among professions and helps identify occupational groups with stronger or weaker credit profiles.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart compares the credit score categories across different occupations and reveals noticeable differences in creditworthiness among professions.
#
# The analysis indicates that some occupations have a higher proportion of customers with Good credit scores, while others have more customers with Standard or Poor credit scores.
#
# Additional insights include:
#
# *   Certain professions are associated with a larger number of customers who maintain Good credit scores, suggesting stronger financial discipline and repayment behavior.
#
# *  Some occupations have a higher concentration of Standard credit scores, indicating average financial stability.
# *   A few occupations show a relatively higher number of Poor credit score customers, which may reflect greater financial challenges or irregular repayment patterns.
#
#
# *   The chart highlights that occupation can influence credit behavior and should be considered during customer risk assessment.
#
#
#
#
#
#
#
# These findings help identify which professional groups are more likely to qualify for different financial products.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The relationship between occupation and credit score provides valuable information for improving business decisions and customer services.
#
# Some positive business impacts include:
#
# *   Designing occupation-specific loan, credit card, and insurance products.
#
# *  Offering premium financial products and lower interest rates to occupations with a higher proportion of Good credit scores.
# *   Creating personalized marketing campaigns for different professional groups.
#
#
# *  Improving credit risk assessment by considering occupation as one of the evaluation factors.
#
# *   Increasing loan approval efficiency by identifying occupations with historically stronger repayment behavior.
#
# These strategies help Paisabazaar deliver personalized financial solutions while reducing lending risk.
#
# **Negative Impacts -** Yes.
#
# The chart may reveal that certain occupations have a higher proportion of customers with Poor credit scores, which can negatively impact business performance.
#
# Reasons include:
#
# *  Some professions may have unstable or irregular income, making loan repayment more difficult.
#
# *   Customers in these occupations may experience more delayed payments and higher outstanding debt.
# *   A higher concentration of Poor credit scores increases the probability of loan defaults.
#
#
# *   Financial institutions may need stricter eligibility checks, additional documentation, or lower loan limits for these occupational groups.
#
#
#
#
#
#
#
#
# Therefore, understanding occupation-wise credit score distribution helps Paisabazaar manage lending risks while making fair and informed credit decisions.

# %% [markdown]
# ####Chart - 7

# %%
# Chart 7 - visuvalization code

# Annual Income vs Outstanding Debt (Hue = Credit Score) – Scatter Plot

# Create a figure with a width of 10 inches and a height of 6 inches
plt.figure(figsize=(10,6))

# Create a scatter plot to visualize the relationship between Annual Income and Outstanding Debt,
# while using different colors to represent Credit Score categories
sns.scatterplot(
    x='Annual_Income',
    y='Outstanding_Debt',
    hue='Credit_Score',
    data=data,
    palette='viridis'
)

# Add a title to the chart
plt.title("Annual Income vs Outstanding Debt by Credit Score")

# Label the x-axis
plt.xlabel("Annual Income")

# Label the y-axis
plt.ylabel("Outstanding Debt")

# Display the legend for Credit Score categories
plt.legend(title="Credit Score")

# Display the scatter plot
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# A Scatter Plot was chosen because it is the most suitable visualization for examining the relationship between two numerical variables, namely Annual Income and Outstanding Debt. By using Credit Score as the hue (color), the chart also incorporates a categorical variable, allowing us to compare how customers with different credit score categories are distributed across various income and debt levels.
#
# This visualization helps identify patterns, clusters, trends, and any unusual observations that may not be visible in individual variable analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot provides a comprehensive view of the relationship between customers' annual income, outstanding debt, and credit score.
#
# Key insights include:
#
# *   Customers with Good Credit Scores are generally concentrated in areas with higher annual income and lower outstanding debt, indicating strong financial health and responsible debt management.
#
# *   Customers with Standard Credit Scores are distributed across moderate income and debt levels, representing average financial stability.
#
# *   Customers with Poor Credit Scores are more frequently observed in regions with higher outstanding debt, regardless of their income level.
# *   The chart may also reveal that some high-income customers still have Poor credit scores, suggesting that income alone does not determine creditworthiness.
#
#
# *    Factors such as repayment history, delayed payments, credit utilization, and existing debt also influence the credit score.
#
#
# *   A few outliers may exist where customers have exceptionally high income or debt, indicating unique financial situations that require further analysis.
#
# Overall, the chart demonstrates that maintaining lower debt is just as important as earning a higher income when it comes to achieving a good credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart help Paisabazaar improve customer evaluation and lending strategies.
#
# Some positive business impacts include:
#
# *   Identifying customers who have high income and low debt, making them ideal candidates for premium loans, higher credit limits, and exclusive financial products.
#
# *  Improving credit risk assessment by considering both income and outstanding debt instead of relying on a single financial indicator.
# *   Designing personalized loan offers based on customers' financial capacity.
# Helping financial advisors recommend appropriate repayment plans and debt management strategies.
#
# *   Enhancing the accuracy of credit score prediction models by understanding the combined influence of multiple financial variables.
#
# These insights support data-driven decision-making and reduce the risk associated with lending.
#
# **Negative Impacts -** Yes.
#
# The chart may reveal that some customers have high outstanding debt despite having high annual income, which can negatively impact business performance.
#
# Reasons include:
#
# *   High income does not always guarantee good financial management.
#
# *   Customers with excessive debt may struggle to repay additional loans, increasing the risk of delayed payments or defaults.
# *   Approving loans based only on income without considering existing debt may expose the company to financial losses.
#
#
# *   Customers with low income and high debt represent an even greater credit risk because they may have limited repayment capacity.
#
# Therefore, Paisabazaar should evaluate both annual income and outstanding debt, along with other financial indicators, before making lending decisions.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# Number of Bank Accounts

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a histogram to visualize the distribution of the number of bank accounts held by customers
sns.histplot(data['Num_Bank_Accounts'], bins=15, color='royalblue')

# Add a title to the chart
plt.title("Distribution of Number of Bank Accounts")

# Label the x-axis
plt.xlabel("Number of Bank Accounts")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the histogram
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram was chosen because Num_Bank_Accounts is a numerical variable. Histograms are ideal for showing how values are distributed across different ranges. This chart helps understand the banking habits of customers by displaying how many bank accounts they typically maintain. It also helps identify common patterns and detect customers with unusually high numbers of bank accounts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most customers maintain only a few bank accounts, while only a small number of customers have a large number of accounts.
#
# Additional insights include:
#
# *   The majority of customers prefer managing a limited number of bank accounts.
#
# *   A smaller group of customers holds multiple bank accounts, which may indicate more complex financial activities.
# *   Customers with fewer accounts may have simpler financial management, while those with many accounts may use different banks for savings, loans, investments, or business purposes.
#
#
# *  The distribution helps understand customers' banking behavior and overall financial engagement.
#
#
#
#
#
#
#
#
# These observations provide useful information about how customers interact with banking services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# Understanding the number of bank accounts held by customers enables Paisabazaar to improve customer segmentation and offer more personalized financial products.
#
# Some positive business impacts include:
#
# *   Identifying customers who actively use banking services.
#
# *  Recommending suitable savings accounts, loans, and investment products based on banking behavior.
# *   Improving customer profiling for credit assessment.
# *   Supporting personalized marketing campaigns for different customer groups.
#
# *   Helping financial institutions understand customer engagement with banking services.
#
# These insights contribute to better product recommendations and improved customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# Customers with an unusually high number of bank accounts may indicate greater financial complexity, which can increase lending risk.
#
# Reasons include:
#
# *   Managing multiple bank accounts may make it more difficult to monitor cash flow and repayment behavior.
#
# *   A high number of accounts could be associated with multiple loans, higher financial commitments, or complex financial activities.
# *   Such customers may require additional verification during the loan approval process.
#
#
# * Increased financial complexity can make credit assessment more challenging and may raise the risk of repayment issues
#
# Therefore, although having multiple bank accounts is not necessarily negative, it should be considered alongside other financial indicators when evaluating a customer's creditworthiness.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Number of Credit Cards Distribution (Histogram)

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a histogram to visualize the distribution of the number of credit cards owned by customers
sns.histplot(data['Num_Credit_Card'], bins=15, color='lightpink')

# Add a title to the chart
plt.title("Distribution of Number of Credit Cards")

# Label the x-axis
plt.xlabel("Number of Credit Cards")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the histogram
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram was chosen because Num_Credit_Card is a numerical variable representing the number of credit cards owned by each customer. Histograms are useful for visualizing the frequency distribution of numerical data, allowing us to identify the most common number of credit cards held by customers, detect unusual values, and understand overall credit card ownership patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows the distribution of credit card ownership among customers.
#
# The analysis reveals that:
#
# *   Most customers own a moderate number of credit cards, indicating balanced use of credit facilities.
#
# *  Only a small percentage of customers have either very few or a large number of credit cards.
#
# *  Customers with a moderate number of credit cards are more likely to manage their credit responsibly.
# *   Customers owning many credit cards may have greater access to credit, but they may also carry higher financial obligations and require closer monitoring.
#
#
# *   The chart helps identify customer spending and borrowing patterns, which are important factors in assessing creditworthiness.
#
# Overall, the distribution provides insights into customers' credit usage behavior and financial management.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart help Paisabazaar understand customer credit usage and improve financial product recommendations.
#
# Some positive business impacts include:
#
# *  Identifying customers who are suitable candidates for additional credit card offers or upgrades.
#
# *   Designing personalized credit card products based on customers' credit usage patterns.
# *   Improving customer segmentation by analyzing credit card ownership.
#
# *   Supporting better credit risk assessment by considering the number of active credit cards.
#
# *  Helping financial institutions recommend appropriate credit limits and repayment plans.
#
# These insights contribute to better customer experience and informed lending decisions.
#
# **Negative Impacts -** Yes.
#
# Customers who own a large number of credit cards may present higher financial risk.
#
# Reasons include:
#
# *  Managing multiple credit cards can increase overall credit utilization and monthly financial commitments.
#
# *   Higher credit card ownership may lead to increased outstanding balances and repayment difficulties if not managed responsibly.
# *   Customers with excessive credit cards may be more likely to miss payments or accumulate debt, which can negatively affect their credit scores.
#
#
# *   Approving additional credit for such customers without proper evaluation may increase the risk of loan defaults and financial losses.
#
# Therefore, while owning multiple credit cards is not inherently negative, it should be assessed together with other financial indicators such as outstanding debt, repayment history, and credit utilization ratio.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Number of Delayed Payment Distribution (Countplot)

#Create a figure with a width of 10 inches and a height of 8 inches
plt.figure(figsize=(10, 8))

#Create a Countplot to visualize the distribution of the number of delayed payments from customers
sns.countplot(x='Num_of_Delayed_Payment', data=data, palette='plasma')

#Add a title to the chart
plt.title("Distribution of Number of Delayed Payments")

#Label the x-axis
plt.xlabel("Number of Delayed Payments")

#Label the y-axis
plt.ylabel("Number of Customers")

#Display the Countplot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Count Plot was chosen because it effectively displays the frequency of each delayed payment count. It shows how many customers have made 0, 1, 2, 3, or more delayed payments. This makes it easy to compare the number of customers in each payment delay category and identify the most common repayment behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The count plot shows the number of customers for each delayed payment count.
#
# The analysis reveals that:
#
# *  Most customers have fewer delayed payments, indicating good repayment discipline.
#
# *   The number of customers decreases as the number of delayed payments increases.
#
# *   Only a small percentage of customers have a high number of delayed payments.
# |
#
#
#
# *   Customers with frequent delayed payments may have poor financial management and lower credit scores.
#
#
# *  Payment history is an important factor in evaluating a customer's creditworthiness and repayment behavior.
#
#
#
#
#
#
#
#
# These insights help understand customer payment patterns and identify customers who may require additional financial evaluation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# Understanding delayed payment behavior enables Paisabazaar to make better lending decisions.
#
# Some positive business impacts include:
#
# *   Identifying customers with strong repayment habits for quicker loan approvals.
#
# *   Improving credit risk assessment using customers' payment history.
# *  Offering better interest rates and premium financial products to customers with fewer delayed payments.
#
# *   Sending payment reminders or financial guidance to customers who frequently delay payments.
#
#
# *   Enhancing the accuracy of credit score prediction models.
#
# These insights help reduce financial risk while improving customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# Customers with a high number of delayed payments represent a greater financial risk.
#
# Reasons include:
#
# *  Frequent delayed payments indicate poor repayment discipline.
#
# *   Such customers are more likely to default on future loans.
# *  Higher loan defaults increase financial losses and recovery costs for the lending institution.
#
#
# *   Approving loans without considering payment history may negatively affect the company's profitability.
#
# Therefore, customers with multiple delayed payments should undergo a more detailed credit assessment before loan approval.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Credit Utilization Ratio Distribution (Box Plot)

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))

# Create a box plot to visualize the distribution of Credit Utilization Ratio
# and identify any outliers
sns.boxplot(y='Credit_Utilization_Ratio', data=data, color='orange')

# Add a title to the chart
plt.title("Distribution of Credit Utilization Ratio")

# Label the y-axis
plt.ylabel("Credit Utilization Ratio (%)")

# Display the box plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Box Plot was chosen because Credit_Utilization_Ratio is a continuous numerical variable. A box plot effectively summarizes the distribution of the data by showing the minimum value, first quartile (Q1), median, third quartile (Q3), maximum value, and potential outliers. It is especially useful for identifying customers whose credit utilization is significantly higher or lower than the majority.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot provides a clear view of customers' credit utilization patterns.
#
# The analysis reveals that:
#
# *  Most customers maintain their credit utilization ratio within a moderate range, indicating balanced use of available credit.
#
# *  A few customers appear as outliers, having exceptionally high credit utilization ratios.
# *  Customers with lower utilization generally demonstrate better financial management and are more likely to maintain healthy credit scores.
#
#
# *   Customers with very high utilization may be relying heavily on their available credit limits, which can negatively affect their creditworthiness.
#
# *   The spread of the data helps understand how consistently customers use their available credit.
#
# Overall, the chart highlights the importance of credit utilization as a key indicator of financial behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar improve credit risk assessment and customer recommendations.
#
# Some positive business impacts include:
#
# *   Identifying customers who manage their credit responsibly.
#
# *   Improving credit score prediction by incorporating credit utilization as a key feature.
#
# *  Offering higher credit limits or premium financial products to customers with healthy utilization ratios.
# *   Providing personalized financial advice to customers with high utilization to improve their credit profile.
# *   Helping lenders make informed decisions regarding loan approvals and credit card issuance.
#
# These insights contribute to more accurate lending decisions and better customer relationship management.
#
# **Negative Impacts -** Yes.
#
# Customers with very high credit utilization ratios may represent a higher financial risk.
#
# Reasons include:
#
# *   High utilization indicates that customers are using a large portion of their available credit limit.
#
# *   Excessive credit usage may suggest financial stress or dependence on borrowed money.
# *   Customers with high utilization are more likely to experience repayment difficulties, delayed payments, and lower credit scores.
#
# *   Approving additional loans or increasing credit limits for such customers without proper assessment can increase the risk of loan defaults and financial losses.
#
# Therefore, customers with consistently high credit utilization should be carefully evaluated before extending additional credit.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Number of Loans vs Interest Rate (line Plot)

# Create a figure with a width of 8 inches and a height of 5 inches
plt.figure(figsize=(8,5))
# Create a line plot to show the relationship between Number of Loans and Average Interest Rate
sns.lineplot( x='Num_of_Loan',
              y='Interest_Rate',
              data=data,
              marker='o',
              color='blue' ) # Show points on the line
# Add a title to the chart
plt.title("Average Interest Rate by Number of Loans")
# Label the x-axis
plt.xlabel("Number of Loans")
# Label the y-axis
plt.ylabel("Average Interest Rate")
# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Line Plot was chosen because Num_of_Loan is an ordered numerical variable (1, 2, 3, 4, …) and Interest_Rate is a continuous numerical variable. Line plots are ideal for showing trends and changes across ordered values.
#
# This chart helps us understand how the average interest rate changes as the number of active loans increases. The connected points make it easier to observe whether the interest rate is increasing, decreasing, or remaining stable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the relationship between the number of loans held by customers and the average interest rate charged to them.
#
# Possible insights:
#
# *   Customers with fewer loans generally receive lower interest rates.
#
# *   As the number of loans increases, the average interest rate tends to increase gradually.
# *  Customers with many active loans may be considered higher-risk borrowers by financial institutions.
#
#
# *   A rising trend suggests that lenders charge higher interest rates to compensate for the increased probability of repayment issues.
#
# *   If the line remains flat, it indicates that the number of loans alone may not significantly influence the interest rate.
#
# Example interpretation
#
# Imagine the chart shows:
#
# 1.  loan → 8%
# 1.   loans → 9%
# 2.   loans → 10.5%
# 2.   loans → 12%
#
# This would indicate a positive relationship between the number of loans and the interest rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# These insights can help Paisabazaar improve lending and recommendation strategies.
#
# Some positive business impacts include:
#
# *  Identify customers who may qualify for lower-interest loans.
# *  Improve credit risk assessment by considering the customer’s existing loan burden.
# *  Offer personalized loan products based on borrowing behavior.
# * Help lenders balance profitability and risk.
#
# *   Support better customer segmentation for marketing and financial advice.
#
# For example, customers with 1–2 loans and good repayment history may be offered premium loan products with attractive interest rates.
#
# **Negative Impacts -** Yes.
#
# If the chart shows that customers with many active loans are charged much higher interest rates, it may indicate increased financial stress.
#
# Specific reasons include:
#
# *   Higher interest rates increase monthly EMI payments.
#
# *  Customers with multiple loans already have higher financial obligations.
#
# *   Increased EMI burden can reduce repayment capacity.
# *  This may lead to delayed payments, higher outstanding debt, and loan defaults.
#
#
# *   A large concentration of such customers can increase the company’s credit risk and recovery costs.
#
# Therefore, approving additional loans to customers with many active loans should be done carefully.

# %% [markdown]
# #### Chart - 13

# %%
# chart - 13 visualization code
# Month vs Amount Invested Monthly (Bar Plot)

# Create a figure with a width of 10 inches and a height of 6 inches
plt.figure(figsize=(10,6))

# Create a bar plot to compare the average monthly investment across different months
sns.barplot(
    x='Month',
    y='Amount_invested_monthly',
    data=data,
    palette='Set3'
)

# Add a title to the chart
plt.title("Average Monthly Investment Across Months")

# Label the x-axis
plt.xlabel("Month")

# Label the y-axis
plt.ylabel("Average Monthly Investment")

# Rotate month labels for better readability
plt.xticks(rotation=45)

# Display the chart
plt.show()

# %%
data['Amount_invested_monthly'].head()
data[['Amount_invested_monthly']].describe()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Bar Plot was selected because Month is a categorical variable and Amount_invested_monthly is a numerical variable. Bar plots are ideal for comparing the average monthly investment amount across different months. This visualization helps identify trends, seasonal variations, and customer investment behavior throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot compares the average amount invested by customers in each month.
#
# The analysis may reveal that:
#
# *   Investment amounts vary from month to month, indicating changes in customers' saving and investment behavior.
#
# *  Some months may show higher average investments, suggesting that customers have greater disposable income or increased interest in investing during those periods.
# *   Other months may have lower investment amounts, which could be due to higher expenses, loan repayments, or seasonal financial commitments.
#
# *   Consistent investment levels across months indicate stable financial planning among customers.
#
# *   The chart helps identify periods when customers are more likely to invest, which can be useful for planning financial campaigns and promotional offers.
#
# Overall, this analysis provides valuable insights into customers' monthly investment patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar improve customer engagement and financial product recommendations.
#
# Some positive business impacts include:
#
# *  Identifying months with higher investment activity for launching investment-related products and promotional campaigns.
#
# *   Offering personalized investment plans based on customers' monthly financial behavior.
# *   Helping financial advisors recommend suitable investment opportunities during periods of higher customer spending capacity.
#
# *   Improving customer segmentation by understanding seasonal investment trends.
#
# *   Supporting strategic planning for financial products and wealth management services.
#
# These insights enable Paisabazaar to better align its services with customer investment habits.
#
# **Negative Impacts -** Yes.
#
# If the chart shows that average monthly investments decline significantly during certain months, it may indicate potential financial challenges for customers.
#
# Reasons include:
#
# *  Customers may prioritize essential expenses or loan repayments over investments during those periods.
#
# *   Lower investment activity may reduce opportunities for cross-selling wealth management products.
# *   A decline in investments could also reflect reduced disposable income or financial uncertainty among customers.
#
#
# *  If this trend continues for several months, it may affect customer portfolio growth and reduce engagement with investment services.
#
# Therefore, Paisabazaar should identify these periods and provide personalized financial guidance or investment incentives to encourage consistent investing.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
# Annual Income vs Monthly Balance (Bubble Plot)

# Create a figure with a width of 10 inches and a height of 6 inches
plt.figure(figsize=(10,6))

# Create a bubble plot
sns.scatterplot(
    x='Annual_Income',              # X-axis: Customer's Annual Income
    y='Monthly_Balance',            # Y-axis: Customer's Monthly Balance
    hue='Credit_Score',             # Different colors for Credit Score categories
    size='Outstanding_Debt',        # Bubble size represents Outstanding Debt
    sizes=(20,300),                 # Minimum and maximum bubble size
    data=data,
    palette='Set2'
)

# Add a title to the chart
plt.title("Annual Income vs Monthly Balance by Credit Score")

# Label the axes
plt.xlabel("Annual Income")
plt.ylabel("Monthly Balance")

# Display the legend
plt.legend(title="Credit Score", bbox_to_anchor=(1.05,1), loc='upper left')

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Bubble Plot was chosen because it allows us to analyze four variables simultaneously, making it an excellent choice for multivariate analysis.
# 1.   X-axis: Annual Income
# 2.   Y-axis: Monthly Balance
# 1.   Bubble Size: Outstanding Debt
# 2.  Bubble Color: Credit Score (Good, Standard, Poor)
#
# Unlike a simple scatter plot, the bubble plot adds an extra dimension by using the size of each bubble to represent the customer's outstanding debt. This helps us understand how income, savings, debt, and credit score interact with one another in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bubble plot provides a comprehensive view of customers' financial health by comparing income, monthly balance, outstanding debt, and credit score.
#
# The analysis may reveal that:
#
#
# *   Customers with higher annual income generally maintain higher monthly balances, indicating better financial stability.
# *  **Larger bubbles** (representing higher outstanding debt) are often associated with customers having **Poor or Standard credit scores.**
# *   **Smaller bubbles** are more common among customers with **Good credit scores**, suggesting lower debt and better financial management.
# *   Some high-income customers may still have large outstanding debts, indicating that a higher income alone does not guarantee good creditworthiness.
# *   Customers with low income, low monthly balance, and high outstanding debt are more likely to belong to the Poor credit score category.
#
# Overall, the chart demonstrates how multiple financial factors work together to influence a customer's credit profile.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar improve credit assessment and customer recommendations.
#
# Some positive business impacts include:
#
# *  Identifying financially stable customers who qualify for premium loan and credit card offers.
#
# *   Detecting high-risk customers by considering multiple financial indicators instead of a single variable.
# *  Improving credit score prediction models by understanding how income, balance, debt, and credit score interact.
#
#
# *   Supporting personalized financial advice based on customers' overall financial health.
#
# *  Helping lenders make more informed loan approval and credit limit decisions.
#
# These insights contribute to better risk management and improved customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# The chart may highlight customer groups that represent a higher financial risk.
#
# Reasons include:
#
# *  Customers with large bubbles (high outstanding debt) but low annual income and low monthly balance may struggle to repay existing loans.
#
# *   Customers with Poor credit scores and significant debt are more likely to experience delayed payments or loan defaults.
# *  Approving additional loans to these customers without proper risk assessment could increase financial losses.
#
# *   High outstanding debt combined with limited disposable income reduces repayment capacity and increases default risk.
#
# Therefore, these customers should be evaluated carefully before extending additional credit.

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code
# Distribution of Customer Payment Behaviour (Count Plot)

# Create a figure with a width of 12 inches and a height of 6 inches
plt.figure(figsize=(12,6))

# Create a count plot to show the number of customers in each payment behaviour category
sns.countplot(
    y='Payment_Behaviour',
    data=data,
    palette='viridis'
)

# Add chart title
plt.title("Distribution of Customer Payment Behaviour")

# Label the axes
plt.xlabel("Number of Customers")
plt.ylabel("Payment Behaviour")

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Count Plot was selected because Payment_Behaviour is a categorical variable. Count plots are ideal for displaying the frequency of each category, allowing us to identify the most and least common payment behaviors among customers. This helps understand customers' repayment habits before performing further analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The count plot shows how customers are distributed across different payment behavior categories.
#
# The analysis may reveal that:
#
# *  Most customers belong to one or two payment behavior categories, indicating common repayment patterns.
#
# *  Some payment behavior categories have significantly fewer customers, making them less common.
# *   Customers with payment behaviors such as Low Spent and Small Value Payments may represent financially disciplined spending habits.
#
#
# *  Customers with behaviors like High Spent and Large Value Payments may indicate higher spending patterns and greater financial commitments.
#
# *  The chart helps identify which payment behavior is most prevalent within the customer base.
#
# Overall, the chart provides a clear understanding of customers' payment habits.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar:
#
# *  Understand the dominant payment behavior among customers.
#
# *  Segment customers based on their spending and payment habits.
# *   Recommend suitable financial products based on customer payment patterns.
# *   Improve credit risk assessment by identifying responsible payment behaviors.
#
# *   Design personalized marketing campaigns for different customer groups.
#
# These insights help the company provide better financial recommendations and improve customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# Some payment behavior categories may indicate higher financial risk.
#
# For example:
#
# *   Customers with High Spent and Large Value Payments may have greater financial obligations and could face repayment challenges if their income is insufficient.
#
# *   Customers showing inconsistent payment behaviors may have a higher probability of delayed payments or loan defaults.
# *   A large number of customers with risky payment behaviors may increase the company's credit risk and potential financial losses.
#
# Therefore, these customer groups should be carefully evaluated before approving new loans or increasing credit limits.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code
# Distribution of Monthly Balance (Histogram)

# Create a figure with a width of 10 inches and a height of 6 inches
plt.figure(figsize=(10,6))

# Create a histogram to visualize the distribution of Monthly Balance
sns.histplot(
    data['Monthly_Balance'],
    bins=30,
    kde=True,
    color='violet'
)

# Add chart title
plt.title("Distribution of Monthly Balance")

# Label the x-axis
plt.xlabel("Monthly Balance")

# Label the y-axis
plt.ylabel("Number of Customers")

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Histogram was chosen because Monthly_Balance is a continuous numerical variable. Histograms are ideal for showing how data is distributed by grouping values into intervals (bins). This chart helps us understand whether customers generally maintain low, medium, or high monthly balances and identifies any skewness or unusual patterns in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram illustrates the distribution of customers' monthly balances.
#
# The analysis may reveal that:
#
# *  Most customers maintain a moderate monthly balance, indicating stable financial management.
#
# *  A smaller number of customers have very high monthly balances, suggesting stronger financial stability.
# *  Some customers have very low monthly balances, which may indicate limited savings or higher monthly expenses.
#
#
# *   If the histogram is right-skewed, it means most customers have lower balances while only a few maintain very high balances.
#
# *  The chart also helps identify any unusual values or outliers in monthly balances.
#
# Overall, the histogram provides a clear understanding of customers' financial position based on their remaining monthly balance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar:
# *   Identify customers with healthy monthly balances who may qualify for premium financial products.
# *   Understand customers' financial capacity before recommending loans or credit cards.
# *   Improve customer segmentation based on available monthly funds.
# *   Support better credit risk assessment by considering customers' remaining monthly balance.
# *   Enable personalized financial planning and investment recommendations.
#
# These insights help the company make informed lending decisions and improve customer satisfaction.
#
# **Negative impacts -** Yes.
#
# Customers with consistently low monthly balances may face financial challenges.
#
# Reasons include:
#
# *   Low monthly balances indicate limited disposable income after meeting monthly expenses.
# *  Such customers may struggle to repay loan EMIs on time.
# *   They are more likely to experience delayed payments, increasing the risk of loan defaults.
# *  Approving high-value loans for these customers without proper assessment may increase financial losses for Paisabazaar.
#
# Therefore, customers with low monthly balances should be carefully evaluated before offering additional credit.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17 visualization code
# Monthly Inhand Salary vs Total EMI per Month (Scatter Plot)

# Create a figure with a width of 10 inches and a height of 6 inches
plt.figure(figsize=(10,6))

# Create a scatter plot to compare Monthly Salary and Total EMI
sns.scatterplot(
    x='Monthly_Inhand_Salary',     # X-axis: Customer's Monthly Salary
    y='Total_EMI_per_month',       # Y-axis: Monthly EMI Amount
    hue='Credit_Score',            # Different colors for Good, Standard and Poor Credit Scores
    data=data,
    palette='Set2'
)

# Add chart title
plt.title("Monthly Inhand Salary vs Total EMI per Month by Credit Score")

# Label the x-axis
plt.xlabel("Monthly Inhand Salary")

# Label the y-axis
plt.ylabel("Total EMI per Month")

# Display legend
plt.legend(title="Credit Score")

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Scatter Plot was selected because both Monthly_Inhand_Salary and Total_EMI_per_month are numerical variables. Scatter plots are the best choice for understanding the relationship between two continuous variables. By adding Credit_Score as the color (hue), the chart becomes a multivariate visualization, allowing us to analyze three variables simultaneously.
#
# This chart helps determine whether customers with higher monthly salaries pay higher EMIs and how this relationship differs among customers with Good, Standard, and Poor credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot compares customers' Monthly Inhand Salary with their Total EMI per Month, while grouping them according to their Credit Score.
#
# The analysis may reveal that:
#
# *  Customers with higher monthly salaries generally have the ability to pay higher EMIs because they have greater income.
#
# *   Customers with Good Credit Scores are often distributed among higher salary ranges and manage their EMI payments more consistently.
# *   Customers with Poor Credit Scores may appear in lower salary ranges while still having relatively high EMI obligations, indicating a higher financial burden.
#
#
# * Some customers with high salaries may still have high EMIs due to larger home loans or personal loans.
#
#
# *   The chart helps identify whether EMI payments are proportional to customers' income or whether some customers are financially overburdened.
#
# Overall, the scatter plot provides a clear understanding of customers' repayment capacity based on their monthly income.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar improve lending decisions and customer recommendations.
#
# Some positive business impacts include:
#
# *   Assessing whether customers have sufficient monthly income to comfortably repay their EMIs.
# *  Identifying financially stable customers who qualify for higher loan amounts.
# *  Recommending appropriate EMI plans based on customers' income levels.
# *   Improving credit risk assessment by considering both salary and repayment obligations.
# *   Supporting personalized financial advice and responsible lending practices.
#
# These insights help reduce lending risk while improving customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# The chart may highlight customers who are at greater financial risk.
#
# Reasons include:
# *   Customers with low monthly salaries but high EMI payments may struggle to meet their repayment obligations.
# *   These customers are more likely to delay payments or default on loans due to limited disposable income.
# *   A concentration of Poor Credit Score customers in this region indicates increased credit risk.
# *  Approving additional loans for such customers without careful assessment could lead to higher default rates and financial losses for Paisabazaar.
#
# Therefore, customers with a high EMI-to-income ratio should undergo thorough financial evaluation before receiving additional credit.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18 visualization code
# Credit Score vs Monthly Balance (Box Plot)

# Create a figure with a width of 8 inches and a height of 6 inches
plt.figure(figsize=(8,6))

# Create a box plot to compare Monthly Balance across Credit Score categories
sns.boxplot(
    x='Credit_Score',          # X-axis: Credit Score categories
    y='Monthly_Balance',       # Y-axis: Monthly Balance
    data=data,
    palette='Set2'
)

# Add chart title
plt.title("Monthly Balance Distribution Across Credit Score Categories")

# Label the axes
plt.xlabel("Credit Score")
plt.ylabel("Monthly Balance")

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Box Plot was chosen because it is the most suitable chart for comparing a numerical variable (Monthly_Balance) across a categorical variable (Credit_Score). It summarizes the distribution of monthly balances by showing the median, quartiles, spread, and outliers for each credit score category. This makes it easy to compare the financial stability of customers with Good, Standard, and Poor credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot compares the distribution of Monthly Balance for customers with different credit score categories.
#
# The analysis may reveal that:
#
# *   Customers with a Good Credit Score generally maintain higher monthly balances, indicating better financial stability and stronger money management.
# *   Customers with a Standard Credit Score usually have moderate monthly balances, suggesting average financial health.
# *  Customers with a Poor Credit Score tend to have lower monthly balances, which may indicate limited savings or higher monthly financial obligations.
# *  The presence of outliers shows that a few customers have exceptionally high or low balances compared to others within the same credit score category.
# *  The spread of each box indicates the variation in monthly balances within each credit score group.
#
# Overall, the chart helps understand how monthly balance is associated with customer creditworthiness.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar in several ways:
#
# *   Identify financially stable customers who are suitable candidates for premium loans or credit cards.
# *  Improve credit assessment by considering customers' available monthly balance along with other financial indicators.
# *  Offer personalized financial products based on customers' financial capacity.
# *   Enhance credit score prediction models by using monthly balance as an important feature.
#
# *   Support better lending decisions and reduce financial risk.
#
# These insights help Paisabazaar provide more accurate recommendations while improving customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# The chart may identify customers with Poor Credit Scores who consistently maintain low monthly balances.
#
# Reasons include:
# *   Low monthly balances indicate limited disposable income after paying monthly expenses.
# *   Such customers may find it difficult to manage additional loan repayments or unexpected financial emergencies.
# *  If loans are approved without considering this factor, the probability of delayed payments and loan defaults may increase.
# *  A large number of customers with low balances can increase the company's overall credit risk and financial losses.
#
# Therefore, monthly balance should be considered as an important factor during the loan approval process.

# %% [markdown]
# #### Chart - 19

# %%
# Chart - 19 visualization code
# Credit Mix vs Credit Score (Count Plot)

# Create figure
plt.figure(figsize=(8,6))

# Create count plot
sns.countplot(
    x='Credit_Mix',
    hue='Credit_Score',
    data=data,
    palette='dark'
)

# Add chart title
plt.title("Credit Score Distribution Across Credit Mix Categories")

# Label axes
plt.xlabel("Credit Mix")
plt.ylabel("Number of Customers")

# Display legend
plt.legend(title="Credit Score")

# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Count Plot was selected because both Credit_Mix and Credit_Score are categorical variables. This chart helps compare the number of customers with Good, Standard, and Poor Credit Scores across different credit mix categories. It is useful for understanding whether the diversity of a customer's credit accounts influences their credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The count plot compares customer credit scores across different Credit Mix categories (such as Good, Standard, and Bad, depending on your dataset).
#
# The analysis may reveal that:
#
# *   Customers with a Good Credit Mix are more likely to have Good Credit Scores.
# *  Customers with a Standard Credit Mix are generally associated with Standard Credit Scores.
# *   Customers with a Bad Credit Mix tend to have a higher proportion of Poor Credit Scores.
# *   The chart clearly shows how the quality of a customer's credit mix is associated with their overall creditworthiness.
#
# Overall, maintaining a balanced credit mix appears to support better credit score outcomes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from this chart can help Paisabazaar:
#
# *   Identify customers with healthy credit portfolios.
# *   Improve credit risk assessment by including credit mix as an important evaluation factor.
# *  Recommend suitable financial products based on customers' credit profiles.
# *   Educate customers about maintaining a balanced mix of secured and unsecured credit.
# *   Improve the accuracy of credit score prediction models.
#
# These insights help reduce lending risk while supporting responsible borrowing.
#
# **Negative Impacts -** Yes.
#
# The chart may show that customers with a Bad Credit Mix are more likely to have Poor Credit Scores.
#
# Reasons include:
# *   A poor credit mix may indicate overdependence on one type of credit or poor credit management.
# *   Customers with poor credit scores may have a higher probability of delayed payments and loan defaults.
# *  Approving loans without considering credit mix may increase financial risk and loan losses for the company.
#
# Therefore, credit mix should be considered an important factor during the credit approval process.

# %% [markdown]
# #### Chart - 20 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Correlation Heatmap of Numerical Features

# Select only numerical columns from the dataset
numerical_data = data.select_dtypes(include='number')

# Create a figure with a width of 14 inches and a height of 10 inches
plt.figure(figsize=(14,10))

# Create a correlation heatmap
sns.heatmap(
    numerical_data.corr(),     # Calculate correlation matrix
    annot=True,                # Display correlation values inside each cell
    cmap='coolwarm',           # Use coolwarm color palette
    fmt='.2f',                 # Show values with 2 decimal places
    linewidths=0.5             # Add lines between cells
)

# Add title
plt.title("Correlation Heatmap of Numerical Features")

# Display the heatmap
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Correlation Heatmap was selected because it is one of the most effective visualizations for multivariate analysis. It allows us to examine the relationships between all numerical variables in the dataset simultaneously.
#
# Unlike scatter plots or bar plots, which compare only two or three variables at a time, a heatmap provides a complete overview of how every numerical feature is related to every other feature. This helps identify the most influential variables for credit score prediction, detect redundant features, and understand customer financial behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap displays the correlation coefficient between every pair of numerical variables.
#
# The correlation values range from -1 to +1:
#
# 1.  +1 → Perfect positive correlation (both variables increase together)
#
# 1.   -1 → Perfect negative correlation (one variable increases while the other decreases)
# 2.    0 → No linear relationship
#
# The analysis may reveal that:
# *  Annual Income may have a positive correlation with Monthly Inhand Salary, indicating that customers with higher annual income generally earn higher monthly salaries.
# *   Outstanding Debt may show a positive correlation with Interest Rate, suggesting that customers carrying larger debts are often charged higher interest rates.
# *  Number of Delayed Payments may positively correlate with Delay from Due Date, indicating that customers who delay payments more frequently also tend to have longer payment delays.
# *  Credit Utilization Ratio may be associated with Outstanding Debt, showing that customers using a larger percentage of their available credit often have higher outstanding balances.
# *  Some variables may have very weak correlations, indicating they contribute unique information to the analysis.
#
# The heatmap provides a quick way to identify the strongest positive and negative relationships among financial variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The insights from the heatmap can significantly improve Paisabazaar's decision-making process.
#
# Some positive business impacts include:
#
# *  Identifying the financial factors that are most strongly related to customer creditworthiness.
#
# *  Selecting the most important variables when building machine learning models for credit score prediction.
# *   Removing highly correlated (redundant) features to simplify the model and improve efficiency.
#
# *  Helping financial institutions better understand customer borrowing behavior.
#
#
# *  Supporting more accurate loan approval decisions and personalized financial product recommendations.
#
# These insights improve both the accuracy of predictive models and the effectiveness of lending strategies.
#
# **Negative Impacts -** Yes.
#
# The heatmap may identify combinations of financial variables associated with higher lending risk.
#
# For example:
#
# *   A strong positive correlation between Outstanding Debt and Interest Rate may indicate that customers with higher debt are charged higher interest rates, increasing their financial burden.
# *  A positive relationship between Number of Delayed Payments and Delay from Due Date may suggest a pattern of poor repayment behavior.
# *  Customers exhibiting these risk factors are more likely to experience financial stress and loan defaults.
# *  Approving loans without considering these correlated risk indicators could increase the company's financial losses.
#
# Therefore, these relationships should be incorporated into the credit assessment process.

# %% [markdown]
# #### Chart - 21 - Pair Plot

# %%
# Pair Plot visualization code
# Pair Plot of Important Financial Features by Credit Score

# Select important numerical features
selected_features = [
    'Annual_Income',
    'Outstanding_Debt',
    'Credit_Utilization_Ratio',
    'Interest_Rate',
    'Credit_Score'
]

# Create Pair Plot
pair_plot = sns.pairplot(
    data[selected_features],
    hue='Credit_Score',
    palette='Set2',
    diag_kind='hist'
)

# Add an overall title
pair_plot.fig.suptitle(
    "Pair Plot of Financial Features by Credit Score",
    y=1.02,
    fontsize=16,
    fontweight='bold'
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pair Plot was selected because it is one of the most effective multivariate visualization techniques for exploratory data analysis. It allows us to examine the relationships between multiple numerical variables at the same time while using different colors to distinguish customers based on their Credit Score (Good, Standard, Poor).
#
# Unlike individual scatter plots, which compare only two variables, a Pair Plot automatically creates all possible pairwise comparisons among the selected variables. This provides a comprehensive understanding of customer financial behavior and helps identify patterns that influence credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Pair Plot compares the relationships among Annual Income, Outstanding Debt, Credit Utilization Ratio, and Interest Rate, while classifying customers according to their Credit Score.
#
# The analysis may reveal that:
# *  Customers with higher annual income generally tend to have lower outstanding debt and are more likely to belong to the Good Credit Score category.
# *   Customers with higher outstanding debt often have higher credit utilization ratios, indicating greater reliance on borrowed credit.
# *   Higher interest rates are commonly associated with customers who have Poor Credit Scores, reflecting increased lending risk.
# *   Customers with Good Credit Scores tend to form clusters with higher income, lower debt, and lower credit utilization.
# *  Customers with Poor Credit Scores may cluster around higher debt, higher utilization, and higher interest rates.
# *   The diagonal histograms show how each individual feature is distributed among customers, helping identify skewness, spread, and concentration of values.
#
# Overall, the Pair Plot helps identify natural customer groups and relationships that are difficult to observe using individual charts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Business Impacts -** Yes.
#
# The Pair Plot provides valuable insights that can help Paisabazaar improve financial decision-making.
#
# Some positive business impacts include:
#
# *   Identifying the financial characteristics of customers with Good, Standard, and Poor credit scores.
# *   Improving customer segmentation for personalized financial products and loan offers.
# *  Selecting the most relevant features for building accurate machine learning models.
# *   Helping financial institutions identify low-risk and high-risk customers more effectively.
# *  Supporting data-driven credit score prediction and better lending strategies.
#
# These insights improve both business efficiency and customer satisfaction.
#
# **Negative Impacts -** Yes.
#
# The Pair Plot may identify customers who exhibit multiple financial risk factors simultaneously.
#
# Reasons include:
#
# *  Customers with low annual income, high outstanding debt, high credit utilization, and high interest rates are more likely to have Poor Credit Scores.
# *  These customers may struggle to repay loans, increasing the likelihood of delayed payments and loan defaults.
# *  Approving additional credit without considering these combined risk factors may increase financial losses for the company.
# *   The chart highlights customer segments that require careful evaluation before loan approval.
#
# Therefore, analyzing multiple financial variables together helps reduce lending risk and improve credit assessment.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis of customer financial data and credit score patterns, the following recommendations are suggested to help Paisabazaar achieve its business objectives:
#
#
# 1.   **Develop an Automated Credit Score Prediction System**
#
#      Implement a machine learning model that accurately predicts customer credit scores using key financial indicators such as annual income, outstanding debt, payment history, credit utilization ratio, and credit mix. This will speed up the credit assessment process and improve decision-making.
#
# 2.  **Strengthen Credit Risk Assessment**
#
#      Give higher importance to customers' payment behavior, delayed payments, outstanding debt, and credit utilization while evaluating loan applications. This will help identify high-risk customers before approving loans.
#
# 1.   **Provide Personalized Financial Products**
#
#      Segment customers based on their credit score and financial profile to offer customized loans, credit cards, investment plans, and insurance products. Personalized recommendations can improve customer satisfaction and business growth.
#
# 1.   **Encourage Responsible Credit Behaviour**
#
#      Educate customers about maintaining a good credit mix, paying EMIs on time, reducing outstanding debt, and keeping credit utilization low. Responsible financial behavior can improve customers' credit scores over time.
#
# 1.   **Monitor High-Risk Customers**
#
#      Customers with poor credit scores, high outstanding debt, frequent delayed payments, and low monthly balances should be monitored closely. Offering financial counseling or repayment assistance can reduce loan default rates.
#
# 2.   **Improve Loan Approval Strategy**
#
#       Instead of relying on a single factor, evaluate multiple financial indicators together, such as income, debt, monthly balance, payment history, and credit utilization. This will result in more accurate and fair lending decisions.
#
# 2.  **Enhance Business Decision-Making Through Data Analytics**
#
#      Regularly analyze customer data using dashboards and visualizations in tools such as Power BI or Tableau. This enables the company to identify trends, monitor portfolio risk, and make data-driven business decisions.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ## **Project Conclusion**
#
# The objective of this project was to analyze customer financial data and classify customers into **Good, Standard, and Poor Credit Score** categories. Through comprehensive **data cleaning, preprocessing, exploratory data analysis (EDA), and visualization**, valuable insights were obtained regarding the factors that influence creditworthiness.
#
# The analysis revealed that **Annual Income, Monthly Inhand Salary, Outstanding Debt, Credit Utilization Ratio, Number of Delayed Payments, Interest Rate, Credit Mix, Payment Behaviour, and Monthly Balance** are among the most influential factors affecting a customer's credit score. Customers with **higher income, lower outstanding debt, timely payments, balanced credit utilization, and healthy monthly balances** generally have better credit scores, whereas customers with **high debt, frequent delayed payments, poor payment behavior, and excessive credit utilization** are more likely to have poor credit scores.
#
# Various **univariate, bivariate, and multivariate visualizations** were used to understand customer financial behavior and identify meaningful relationships among variables. These visualizations provided valuable insights into customer segmentation, repayment patterns, and lending risk, enabling a deeper understanding of credit score classification.
#
# Overall, this analysis demonstrates that **data analytics and machine learning can significantly improve the credit assessment process**. By leveraging these insights, Paisabazaar can make more informed loan approval decisions, reduce loan default risk, provide personalized financial product recommendations, and enhance customer satisfaction. This project highlights the importance of data-driven decision-making in the financial services industry and provides a strong foundation for building an accurate credit score prediction model.
